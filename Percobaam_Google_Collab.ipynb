# %% [markdown]
# <a href="https://colab.research.google.com/github/Hilal1912/pm-turi1-eda/blob/main/Percobaam_Google_Collab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib

print("--- Versi Pustaka Python ---")
print(f"Scikit-Learn : {sklearn.__version__}")
print(f"Pandas       : {pd.__version__}")
print(f"NumPy        : {np.__version__}")
print(f"Matplotlib   : {matplotlib.__version__}")
# Out:
# --- Versi Pustaka Python ---
# Scikit-Learn : 1.6.1
# Pandas       : 2.2.3
# NumPy        : 2.1.3
# Matplotlib   : 3.10.0
